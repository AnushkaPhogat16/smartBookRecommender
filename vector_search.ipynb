# %%
pip install -U langchain langchain-community langchain-openai langchain-text-splitters chromadb
# Out:
# Collecting langchain
#   Downloading langchain-0.3.24-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 5.8 MB/s eta 0:00:00
# Collecting langchain-community
#   Downloading langchain_community-0.3.23-py3-none-any.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 14.6 MB/s eta 0:00:00
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.14-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.4/62.4 kB 3.5 MB/s eta 0:00:00
# Collecting langchain-text-splitters
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Collecting chromadb
#   Downloading chromadb-1.0.7-cp39-abi3-win_amd64.whl (18.3 MB)
#      ---------------------------------------- 18.3/18.3 MB 8.8 MB/s eta 0:00:00
# Collecting langchain-core<1.0.0,>=0.3.55
#   Downloading langchain_core-0.3.56-py3-none-any.whl (437 kB)
#      ------------------------------------- 437.2/437.2 kB 13.8 MB/s eta 0:00:00
# Collecting pydantic<3.0.0,>=2.7.4
#   Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
#      ------------------------------------- 443.9/443.9 kB 14.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\anush\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\anush\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Requirement already satisfied: requests<3,>=2 in c:\users\anush\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Collecting langsmith<0.4,>=0.1.17
#   Downloading langsmith-0.3.39-py3-none-any.whl (359 kB)
#      ------------------------------------- 359.4/359.4 kB 21.8 MB/s eta 0:00:00
# Collecting tenacity!=8.4.0,<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# Collecting httpx-sse<1.0.0,>=0.4.0
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting numpy>=1.26.2
#   Downloading numpy-2.2.5-cp310-cp310-win_amd64.whl (12.9 MB)
#      --------------------------------------- 12.9/12.9 MB 13.4 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.11.18-cp310-cp310-win_amd64.whl (442 kB)
#      -------------------------------------- 442.9/442.9 kB 9.2 MB/s eta 0:00:00
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting openai<2.0.0,>=1.68.2
#   Downloading openai-1.76.2-py3-none-any.whl (661 kB)
#      ------------------------------------- 661.3/661.3 kB 10.3 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.7
#   Downloading tiktoken-0.9.0-cp310-cp310-win_amd64.whl (894 kB)
#      ------------------------------------- 894.0/894.0 kB 14.0 MB/s eta 0:00:00
# Collecting typing-extensions>=4.5.0
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.8/45.8 kB 2.2 MB/s eta 0:00:00
# Collecting httpx>=0.27.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Collecting typer>=0.9.0
#   Downloading typer-0.15.3-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.3/45.3 kB 2.2 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.21.1-cp310-cp310-win_amd64.whl (12.3 MB)
#      --------------------------------------- 12.3/12.3 MB 10.7 MB/s eta 0:00:00
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.18-cp310-cp310-win_amd64.whl (134 kB)
#      -------------------------------------- 134.6/134.6 kB 8.3 MB/s eta 0:00:00
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting chroma-hnswlib==0.7.6
#   Downloading chroma_hnswlib-0.7.6-cp310-cp310-win_amd64.whl (150 kB)
#      -------------------------------------- 151.0/151.0 kB 8.8 MB/s eta 0:00:00
# Collecting jsonschema>=4.19.0
#   Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#      ---------------------------------------- 88.5/88.5 kB 4.9 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.5/62.5 kB 1.6 MB/s eta 0:00:00
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.32.1-py3-none-any.whl (118 kB)
#      -------------------------------------- 119.0/119.0 kB 3.5 MB/s eta 0:00:00
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 7.9 MB/s eta 0:00:00
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
#      -------------------------------------- 152.8/152.8 kB 4.6 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.32.1-py3-none-any.whl (18 kB)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-5.1.0-cp310-cp310-win_amd64.whl (41 kB)
#      ---------------------------------------- 41.5/41.5 kB 2.0 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.6 MB/s eta 0:00:00
# Collecting fastapi==0.115.9
#   Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.9/94.9 kB 5.6 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 9.7 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-14.0.0-py3-none-any.whl (243 kB)
#      -------------------------------------- 243.2/243.2 kB 7.5 MB/s eta 0:00:00
# Collecting build>=1.0.3
#   Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.32.1-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.3/65.3 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in c:\users\anush\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting posthog>=2.4.0
#   Downloading posthog-4.0.1-py2.py3-none-any.whl (92 kB)
#      ---------------------------------------- 92.0/92.0 kB 2.6 MB/s eta 0:00:00
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 10.5 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.53b1-py3-none-any.whl (12 kB)
# Collecting starlette<0.46.0,>=0.40.0
#   Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.5/71.5 kB 3.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.6.0-cp310-cp310-win_amd64.whl (120 kB)
#      -------------------------------------- 120.8/120.8 kB 3.6 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.1-cp310-cp310-win_amd64.whl (45 kB)
#      ---------------------------------------- 45.2/45.2 kB 2.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\anush\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (22.1.0)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.0-cp310-cp310-win_amd64.whl (92 kB)
#      ---------------------------------------- 92.9/92.9 kB 5.5 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.4.3-cp310-cp310-win_amd64.whl (38 kB)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\anush\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\anush\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (22.0)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: colorama in c:\users\anush\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.9/50.9 kB 1.3 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.8/78.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\anush\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2022.12.7)
# Requirement already satisfied: anyio in c:\users\anush\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: idna in c:\users\anush\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.24.0-cp310-cp310-win_amd64.whl (234 kB)
#      -------------------------------------- 234.6/234.6 kB 4.9 MB/s eta 0:00:00
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.4.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting durationpy>=0.7
#   Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: requests-oauthlib in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.26.14)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\anush\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.22.0)
# Collecting packaging>=19.1
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB 1.4 MB/s eta 0:00:00
# Collecting zstandard<0.24.0,>=0.23.0
#   Downloading zstandard-0.23.0-cp310-cp310-win_amd64.whl (495 kB)
#      -------------------------------------- 495.5/495.5 kB 7.7 MB/s eta 0:00:00
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: sympy in c:\users\anush\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: flatbuffers in c:\users\anush\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\anush\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sniffio in c:\users\anush\anaconda3\lib\site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.2.0)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.9.0-cp310-cp310-win_amd64.whl (208 kB)
#      -------------------------------------- 208.4/208.4 kB 6.4 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting importlib-metadata<8.7.0,>=6.0
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.32.1
#   Downloading opentelemetry_exporter_otlp_proto_common-1.32.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\anush\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.60.0)
# Collecting opentelemetry-proto==1.32.1
#   Downloading opentelemetry_proto-1.32.1-py3-none-any.whl (55 kB)
#      ---------------------------------------- 55.9/55.9 kB 2.9 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
#      -------------------------------------- 434.5/434.5 kB 6.7 MB/s eta 0:00:00
# Collecting opentelemetry-semantic-conventions==0.53b1
#   Downloading opentelemetry_semantic_conventions-0.53b1-py3-none-any.whl (188 kB)
#      -------------------------------------- 188.4/188.4 kB 3.8 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation==0.53b1
#   Downloading opentelemetry_instrumentation-0.53b1-py3-none-any.whl (30 kB)
# Collecting opentelemetry-util-http==0.53b1
#   Downloading opentelemetry_util_http-0.53b1-py3-none-any.whl (7.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.53b1
#   Downloading opentelemetry_instrumentation_asgi-0.53b1-py3-none-any.whl (16 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\anush\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.53b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 5.9 MB/s eta 0:00:00
# Collecting python-dotenv>=0.21.0
#   Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\anush\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 7.1 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\anush\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\anush\anaconda3\lib\site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
#      -------------------------------------- 481.4/481.4 kB 7.6 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\anush\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Collecting httptools>=0.6.3
#   Downloading httptools-0.6.4-cp310-cp310-win_amd64.whl (88 kB)
#      ---------------------------------------- 88.3/88.3 kB 2.5 MB/s eta 0:00:00
# Collecting websockets>=10.4
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
#      -------------------------------------- 176.8/176.8 kB 3.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13
#   Downloading watchfiles-1.0.5-cp310-cp310-win_amd64.whl (291 kB)
#      -------------------------------------- 291.5/291.5 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\anush\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\anush\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\anush\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.5/294.5 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\anush\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.9.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      -------------------------------------- 194.4/194.4 kB 4.0 MB/s eta 0:00:00
# Collecting zipp>=3.20
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\anush\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.55->langchain) (2.1)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting anyio
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      -------------------------------------- 100.9/100.9 kB 2.9 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\anush\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (0.4.3)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\anush\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 83.2/83.2 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\anush\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53914 sha256=0c5b62d31e8c3aa4db699eddcac66a84f0e492af9e6dca667537c6aac98345de
#   Stored in directory: c:\users\anush\appdata\local\pip\cache\wheels\c4\41\b6\f76a356f0791da799545c23894ceae842eeff054d0eb1fb626
# Successfully built pypika
# Installing collected packages: pypika, durationpy, zstandard, zipp, websockets, typing-extensions, tqdm, tenacity, shellingham, rpds-py, python-dotenv, pyreadline3, pyproject_hooks, pygments, protobuf, propcache, packaging, overrides, orjson, opentelemetry-util-http, numpy, mmh3, mdurl, jsonpatch, jiter, httpx-sse, httptools, h11, grpcio, fsspec, frozenlist, exceptiongroup, distro, deprecated, bcrypt, backoff, attrs, async-timeout, annotated-types, aiohappyeyeballs, uvicorn, typing-inspection, typing-inspect, tiktoken, requests-toolbelt, referencing, pydantic-core, posthog, opentelemetry-proto, multidict, marshmallow, markdown-it-py, importlib-metadata, humanfriendly, huggingface-hub, httpcore, googleapis-common-protos, chroma-hnswlib, build, asgiref, anyio, aiosignal, yarl, watchfiles, tokenizers, starlette, rich, pydantic, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, kubernetes, jsonschema-specifications, httpx, dataclasses-json, coloredlogs, typer, pydantic-settings, opentelemetry-semantic-conventions, openai, onnxruntime, langsmith, jsonschema, fastapi, aiohttp, opentelemetry-sdk, opentelemetry-instrumentation, langchain-core, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain-openai, opentelemetry-instrumentation-fastapi, langchain, langchain-community, chromadb
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.19.0
#     Uninstalling zstandard-0.19.0:
#       Successfully uninstalled zstandard-0.19.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.11.0
#     Uninstalling zipp-3.11.0:
#       Successfully uninstalled zipp-3.11.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 22.0
#     Uninstalling packaging-22.0:
#       Successfully uninstalled packaging-22.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.32
#     Uninstalling jsonpatch-1.32:
#       Successfully uninstalled jsonpatch-1.32
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.57.0
#     Uninstalling grpcio-1.57.0:
#       Successfully uninstalled grpcio-1.57.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 0.9.1
#     Uninstalling requests-toolbelt-0.9.1:
#       Successfully uninstalled requests-toolbelt-0.9.1
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.60.0
#     Uninstalling googleapis-common-protos-1.60.0:
#       Successfully uninstalled googleapis-common-protos-1.60.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.17.3
#     Uninstalling jsonschema-4.17.3:
#       Successfully uninstalled jsonschema-4.17.3
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.9.0 asgiref-3.8.1 async-timeout-4.0.3 attrs-25.3.0 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-1.0.7 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.18 distro-1.9.0 durationpy-0.9 exceptiongroup-1.2.2 fastapi-0.115.9 frozenlist-1.6.0 fsspec-2025.3.2 googleapis-common-protos-1.70.0 grpcio-1.71.0 h11-0.16.0 httpcore-1.0.9 httptools-0.6.4 httpx-0.28.1 httpx-sse-0.4.0 huggingface-hub-0.30.2 humanfriendly-10.0 importlib-metadata-8.6.1 jiter-0.9.0 jsonpatch-1.33 jsonschema-4.23.0 jsonschema-specifications-2025.4.1 kubernetes-32.0.1 langchain-0.3.24 langchain-community-0.3.23 langchain-core-0.3.56 langchain-openai-0.3.14 langchain-text-splitters-0.3.8 langsmith-0.3.39 markdown-it-py-3.0.0 marshmallow-3.26.1 mdurl-0.1.2 mmh3-5.1.0 multidict-6.4.3 numpy-2.2.5 onnxruntime-1.21.1 openai-1.76.2 opentelemetry-api-1.32.1 opentelemetry-exporter-otlp-proto-common-1.32.1 opentelemetry-exporter-otlp-proto-grpc-1.32.1 opentelemetry-instrumentation-0.53b1 opentelemetry-instrumentation-asgi-0.53b1 opentelemetry-instrumentation-fastapi-0.53b1 opentelemetry-proto-1.32.1 opentelemetry-sdk-1.32.1 opentelemetry-semantic-conventions-0.53b1 opentelemetry-util-http-0.53b1 orjson-3.10.18 overrides-7.7.0 packaging-24.2 posthog-4.0.1 propcache-0.3.1 protobuf-5.29.4 pydantic-2.11.4 pydantic-core-2.33.2 pydantic-settings-2.9.1 pygments-2.19.1 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.1.0 referencing-0.36.2 requests-toolbelt-1.0.0 rich-14.0.0 rpds-py-0.24.0 shellingham-1.5.4 starlette-0.45.3 tenacity-9.1.2 tiktoken-0.9.0 tokenizers-0.21.1 tqdm-4.67.1 typer-0.15.3 typing-extensions-4.13.2 typing-inspect-0.9.0 typing-inspection-0.4.0 uvicorn-0.34.2 watchfiles-1.0.5 websockets-15.0.1 yarl-1.20.0 zipp-3.21.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# transformers 4.24.0 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.21.1 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 2.2.5 which is incompatible.
# tensorflow-intel 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.13.2 which is incompatible.
# scipy 1.10.0 requires numpy<1.27.0,>=1.19.5, but you have numpy 2.2.5 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 2.2.5 which is incompatible.
# jupyter-server 1.23.4 requires anyio<4,>=3.1.0, but you have anyio 4.9.0 which is incompatible.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 books = pd.read_csv("books_cleaned.csv")
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\compat\__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\compat\numpy\__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\util\__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\util\_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\_libs\__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File c:\Users\anush\anaconda3\lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
